# %% [markdown]
# # pandas
# 1. what kind of data does pandas handle?

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
pd.__version__
# Out:
# '1.2.4'

# %%
details_df = pd.DataFrame({"name":["yazh","chaitu"], "age":[30,5]})

# %%
details_df
# Out:
#      name  age
# 0    yazh   30
# 1  chaitu    5

# %%
#https://pandas.pydata.org/docs/getting_started/intro_tutorials/01_table_oriented.html#min-tut-01-tableoriented

# %%
titanic_df = pd.DataFrame(
    {
        "Name": [
            "Braund, Mr. Owen Harris",
            "Allen, Mr. William Henry",
            "Bonnell, Miss. Elizabeth",
        
    ],
        "Age": [22, 35, 58],
        "Sex": ["Male", "Male", "Female"]
        
    })

# %%
titanic_df
# Out:
#                        Name  Age     Sex
# 0   Braund, Mr. Owen Harris   22    Male
# 1  Allen, Mr. William Henry   35    Male
# 2  Bonnell, Miss. Elizabeth   58  Female

# %%
titanic_df["Age"]
# Out:
# 0    22
# 1    35
# 2    58
# Name: Age, dtype: int64

# %%
titanic_df["Name"]
# Out:
# 0     Braund, Mr. Owen Harris
# 1    Allen, Mr. William Henry
# 2    Bonnell, Miss. Elizabeth
# Name: Name, dtype: object

# %%
titanic_df["Sex"]
# Out:
# 0      Male
# 1      Male
# 2    Female
# Name: Sex, dtype: object

# %%
#creating a series from scratch

#create passenger class

passenger_class = pd.Series([1, 1, 1], name="passenger class")

# %%
passenger_class
# Out:
# 0    1
# 1    1
# 2    1
# Name: passenger class, dtype: int64

# %%
titanic_df
# Out:
#                        Name  Age     Sex
# 0   Braund, Mr. Owen Harris   22    Male
# 1  Allen, Mr. William Henry   35    Male
# 2  Bonnell, Miss. Elizabeth   58  Female

# %%
titanic_df.insert(3,"passenger_class", 1)

# %%
titanic_df
# Out:
#                        Name  Age     Sex  passenger_class
# 0   Braund, Mr. Owen Harris   22    Male                1
# 1  Allen, Mr. William Henry   35    Male                1
# 2  Bonnell, Miss. Elizabeth   58  Female                1

# %%
titanic_df["Age"].max()
# Out:
# 58

# %%
titanic_df.describe()
# Out:
#              Age  passenger_class
# count   3.000000              3.0
# mean   38.333333              1.0
# std    18.230012              0.0
# min    22.000000              1.0
# 25%    28.500000              1.0
# 50%    35.000000              1.0
# 75%    46.500000              1.0
# max    58.000000              1.0

# %% [markdown]
# # 2. how do i read and write tabular data

# %%
titanic = pd.read_csv(r"C:\yazh\train.csv")

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
titanic.tail(25)
# Out:
#      PassengerId  Survived  Pclass  \
# 866          867         1       2
# 867          868         0       1
# 868          869         0       3
# 869          870         1       3
# 870          871         0       3
# 871          872         1       1
# 872          873         0       1
# 873          874         0       3
# 874          875         1       2
# 875          876         1       3
# 876          877         0       3
# 877          878         0       3
# 878          879         0       3
# 879          880         1       1
# 880          881         1       2
# 881          882         0       3
# 882          883         0       3
# 883          884         0       2
# 884          885         0       3
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
# ...

# %%
titanic.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
titanic.to_excel("titanic.xlsx", sheet_name= "passengers", index = False)

# %%
titanic= pd.read_excel("titanic.xlsx",sheet_name= "passengers")

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# ## 3. How do I select a subset of a DataFrame?

# %%
titanic = pd.read_csv(r"C:\yazh\train.csv")
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic_name = titanic["Name"]

# %%
titanic_name
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
type(titanic["Name"])
# Out:
# pandas.core.series.Series

# %%
titanic_age_sex = titanic[["Age", "Sex"]]
titanic_age_sex.head(5)
# Out:
#     Age     Sex
# 0  22.0    male
# 1  38.0  female
# 2  26.0  female
# 3  35.0  female
# 4  35.0    male

# %%
titanic_name_age_sex = titanic[["Name", "Age", "Sex"]]
titanic_name_age_sex.head(5)
# Out:
#                                                 Name   Age     Sex
# 0                            Braund, Mr. Owen Harris  22.0    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0  female
# 2                             Heikkinen, Miss. Laina  26.0  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0  female
# 4                           Allen, Mr. William Henry  35.0    male

# %%
titanic["Age"].max()
# Out:
# 80.0

# %%
titanic["Age"].min()
# Out:
# 0.42

# %%
##how do i filter specific rows from a DF?

# %%
age_above_35 =titanic[titanic["Age"]<5]
age_above_35
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 7              8         0       3            Palsson, Master. Gosta Leonard
# 10            11         1       3           Sandstrom, Miss. Marguerite Rut
# 16            17         0       3                      Rice, Master. Eugene
# 43            44         1       2  Laroche, Miss. Simonne Marie Anne Andree
# 63            64         0       3                     Skoog, Master. Harald
# 78            79         1       2             Caldwell, Master. Alden Gates
# 119          120         0       3         Andersson, Miss. Ellis Anna Maria
# 164          165         0       3              Panula, Master. Eino Viljami
# 171          172         0       3                      Rice, Master. Arthur
# 172          173         1       3              Johnson, Miss. Eleanor Ileen
# 183          184         1       2                 Becker, Master. Richard F
# ...

# %%
sandstrom_rut = titanic[titanic["Name"] == "Sandstrom, Miss. Marguerite Rut"]
sandstrom_rut
# Out:
#     PassengerId  Survived  Pclass                             Name     Sex  \
# 10           11         1       3  Sandstrom, Miss. Marguerite Rut  female
#
#     Age  SibSp  Parch   Ticket  Fare Cabin Embarked
# 10  4.0      1      1  PP 9549  16.7    G6        S

# %%
first_class = titanic[titanic["Pclass"]==1]
first_class.head(5)
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 3             4         1       1
# 6             7         0       1
# 11           12         1       1
# 23           24         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
# 23                       Sloper, Mr. William Thompson    male  28.0      0
#
#     Parch    Ticket     Fare Cabin Embarked
# 1       0  PC 17599  71.2833   C85        C
# 3       0    113803  53.1000  C123        S
# 6       0     17463  51.8625   E46        S
# 11      0    113783  26.5500  C103        S
# 23      0    113788  35.5000    A6        S

# %%
second_class = titanic[titanic["Pclass"]==2]
second_class.head(5)
# Out:
#     PassengerId  Survived  Pclass                                 Name  \
# 9            10         1       2  Nasser, Mrs. Nicholas (Adele Achem)
# 15           16         1       2     Hewlett, Mrs. (Mary D Kingcome)
# 17           18         1       2         Williams, Mr. Charles Eugene
# 20           21         0       2                 Fynney, Mr. Joseph J
# 21           22         1       2                Beesley, Mr. Lawrence
#
#        Sex   Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# 9   female  14.0      1      0  237736  30.0708   NaN        C
# 15  female  55.0      0      0  248706  16.0000   NaN        S
# 17    male   NaN      0      0  244373  13.0000   NaN        S
# 20    male  35.0      0      0  239865  26.0000   NaN        S
# 21    male  34.0      0      0  248698  13.0000   D56        S

# %%
third_class = titanic[titanic["Pclass"]==3]
third_class.head(5)
# Out:
#    PassengerId  Survived  Pclass                            Name     Sex  \
# 0            1         0       3         Braund, Mr. Owen Harris    male
# 2            3         1       3          Heikkinen, Miss. Laina  female
# 4            5         0       3        Allen, Mr. William Henry    male
# 5            6         0       3                Moran, Mr. James    male
# 7            8         0       3  Palsson, Master. Gosta Leonard    male
#
#     Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0  22.0      1      0         A/5 21171   7.2500   NaN        S
# 2  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 4  35.0      0      0            373450   8.0500   NaN        S
# 5   NaN      0      0            330877   8.4583   NaN        Q
# 7   2.0      3      1            349909  21.0750   NaN        S

# %%
##I’m interested in the Titanic passengers from cabin class 2 and 3.

# %%
class_2and3 = titanic[titanic["Pclass"].isin([2,3])]
class_2and3.head(5)
# Out:
#    PassengerId  Survived  Pclass                            Name     Sex  \
# 0            1         0       3         Braund, Mr. Owen Harris    male
# 2            3         1       3          Heikkinen, Miss. Laina  female
# 4            5         0       3        Allen, Mr. William Henry    male
# 5            6         0       3                Moran, Mr. James    male
# 7            8         0       3  Palsson, Master. Gosta Leonard    male
#
#     Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0  22.0      1      0         A/5 21171   7.2500   NaN        S
# 2  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 4  35.0      0      0            373450   8.0500   NaN        S
# 5   NaN      0      0            330877   8.4583   NaN        Q
# 7   2.0      3      1            349909  21.0750   NaN        S

# %%
##I want to work with passenger data for which the age is known.

age_no_na = titanic[titanic["Age"].notna()]
age_no_na.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#complete 3 in pandas document
age_no_na = titanic[titanic["Age"].notna() == 0]
age_no_na.head(5)
# Out:
#     PassengerId  Survived  Pclass                           Name     Sex  Age  \
# 5             6         0       3               Moran, Mr. James    male  NaN
# 17           18         1       2   Williams, Mr. Charles Eugene    male  NaN
# 19           20         1       3        Masselmani, Mrs. Fatima  female  NaN
# 26           27         0       3        Emir, Mr. Farred Chehab    male  NaN
# 28           29         1       3  O'Dwyer, Miss. Ellen "Nellie"  female  NaN
#
#     SibSp  Parch  Ticket     Fare Cabin Embarked
# 5       0      0  330877   8.4583   NaN        Q
# 17      0      0  244373  13.0000   NaN        S
# 19      0      0    2649   7.2250   NaN        C
# 26      0      0    2631   7.2250   NaN        C
# 28      0      0  330959   7.8792   NaN        Q

# %%
above_60_adult = titanic.loc[titanic["Age"] > 60, "Name"]
above_60_adult
# Out:
# 33                         Wheadon, Mr. Edward H
# 54                Ostby, Mr. Engelhart Cornelius
# 96                     Goldschmidt, Mr. George B
# 116                         Connors, Mr. Patrick
# 170                    Van der hoef, Mr. Wyckoff
# 252                    Stead, Mr. William Thomas
# 275            Andrews, Miss. Kornelia Theodosia
# 280                             Duane, Mr. Frank
# 326                    Nysveen, Mr. Johan Hansen
# 438                            Fortune, Mr. Mark
# 456                    Millet, Mr. Francis Davis
# 483                       Turkula, Mrs. (Hedwig)
# 493                      Artagaveytia, Mr. Ramon
# 545                 Nicholson, Mr. Arthur Ernest
# 555                           Wright, Mr. George
# 570                           Harris, Mr. George
# 625                        Sutton, Mr. Frederick
# 630         Barkworth, Mr. Algernon Henry Wilson
# 672                  Mitchell, Mr. Henry Michael
# ...

# %%
above_60_adult.shape
# Out:
# (22,)

# %%
titanic.iloc[0:891, 2:5].head(5)
# Out:
#    Pclass                                               Name     Sex
# 0       3                            Braund, Mr. Owen Harris    male
# 1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2       3                             Heikkinen, Miss. Laina  female
# 3       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4       3                           Allen, Mr. William Henry    male

# %% [markdown]
# REMEMBER
#
# When selecting subsets of data, square brackets [] are used.
#
# Inside these brackets, you can use a single column/row label, a list of column/row labels, a slice of labels, a conditional expression or a colon.
#
# Select specific rows and/or columns using loc when using the row and column names
#
# Select specific rows and/or columns using iloc when using the positions in the table
#
# You can assign new values to a selection based on loc/iloc.

# %% [markdown]
# ##4.How to create plots in pandas

# %%
#first import the matplotlib library
#import matplotlib.pyplot as plt


air_quality_try = pd.read_csv(r'C:\yazh\air_quality_no2.csv')#,index_col = 0, parse_dates = True)
air_quality_try.head(5)
# Out:
#               datetime  station_antwerp  station_paris  station_london
# 0  2019-05-07 02:00:00              NaN            NaN            23.0
# 1  2019-05-07 03:00:00             50.5           25.0            19.0
# 2  2019-05-07 04:00:00             45.0           27.7            19.0
# 3  2019-05-07 05:00:00              NaN           50.4            16.0
# 4  2019-05-07 06:00:00              NaN           61.9             NaN

# %%
air_quality_try.dtypes
# Out:
# datetime            object
# station_antwerp    float64
# station_paris      float64
# station_london     float64
# dtype: object

# %%
air_quality_try.plot()
# Out:
# <AxesSubplot:>

# %%
air_quality = pd.read_csv(r'C:\yazh\air_quality_no2.csv',index_col = 0, 
                          parse_dates = True)
air_quality.head(5)

#(What is Parse_date in Python?
#Description. Parse a date from a string. 
#This function uses the date format for the locale as a hint to 
#determine the order in which the date fields appear in the string.)
# Out:
#                      station_antwerp  station_paris  station_london
# datetime
# 2019-05-07 02:00:00              NaN            NaN            23.0
# 2019-05-07 03:00:00             50.5           25.0            19.0
# 2019-05-07 04:00:00             45.0           27.7            19.0
# 2019-05-07 05:00:00              NaN           50.4            16.0
# 2019-05-07 06:00:00              NaN           61.9             NaN

# %%
air_quality.dtypes
# Out:
# station_antwerp    float64
# station_paris      float64
# station_london     float64
# dtype: object

# %%
air_quality.info
# Out:
# <bound method DataFrame.info of                      station_antwerp  station_paris  station_london
# datetime
# 2019-05-07 02:00:00              NaN            NaN            23.0
# 2019-05-07 03:00:00             50.5           25.0            19.0
# 2019-05-07 04:00:00             45.0           27.7            19.0
# 2019-05-07 05:00:00              NaN           50.4            16.0
# 2019-05-07 06:00:00              NaN           61.9             NaN
# ...                              ...            ...             ...
# 2019-06-20 22:00:00              NaN           21.4             NaN
# 2019-06-20 23:00:00              NaN           24.9             NaN
# 2019-06-21 00:00:00              NaN           26.5             NaN
# 2019-06-21 01:00:00              NaN           21.8             NaN
# 2019-06-21 02:00:00              NaN           20.0             NaN
#
# [1035 rows x 3 columns]>

# %%
#4.how to create plots in pandas?

#i want a quick visual check of the data

air_quality.plot()
#"""With a DataFrame, pandas creates by default one line 
#plot for each of the columns with numeric data."""
# Out:
# <AxesSubplot:xlabel='datetime'>

# %%
#I want to plot only the columns of the data table with the data from Paris.

air_quality["station_paris"].plot()

#To plot a specific column, use the selection method of the 
#subset data tutorial in combination with the plot() method. Hence, 
#the plot() method works on both Series and DataFrame.
# Out:
# <AxesSubplot:xlabel='datetime'>

# %%
#I want to visually compare the N02 values measured in London versus Paris.
air_quality.plot.scatter(x="station_london", y= "station_paris", 
                         alpha = 0.289)
# Out:
# <AxesSubplot:xlabel='station_london', ylabel='station_paris'>

# %%
air_quality.plot.box()
# Out:
# <AxesSubplot:>

# %%
axs = air_quality.plot.area(figsize = (12,4), subplots = True)

# %%
air_quality
# Out:
#                      station_antwerp  station_paris  station_london
# datetime
# 2019-05-07 02:00:00              NaN            NaN            23.0
# 2019-05-07 03:00:00             50.5           25.0            19.0
# 2019-05-07 04:00:00             45.0           27.7            19.0
# 2019-05-07 05:00:00              NaN           50.4            16.0
# 2019-05-07 06:00:00              NaN           61.9             NaN
# ...                              ...            ...             ...
# 2019-06-20 22:00:00              NaN           21.4             NaN
# 2019-06-20 23:00:00              NaN           24.9             NaN
# 2019-06-21 00:00:00              NaN           26.5             NaN
# 2019-06-21 01:00:00              NaN           21.8             NaN
# 2019-06-21 02:00:00              NaN           20.0             NaN
#
# [1035 rows x 3 columns]

# %% [markdown]
# REMEMBER
#
# The .plot.* methods are applicable on both Series and DataFrames
#
# By default, each of the columns is plotted as a different element (line, boxplot,…)
#
# Any plot created by pandas is a Matplotlib object.

# %%
## 5.how to create new column derived from existing column?

#I want to express the NO2 concentration of the station in London in mg/m3
#(If we assume temperature of 25 degrees Celsius and pressure of 1013 hPa, 
#the conversion factor is 1.882)

# %%
air_quality["london_mg_per_cubic"] = air_quality["station_london"] * 1.882
air_quality.head()
# Out:
#                      station_antwerp  station_paris  station_london  \
# datetime
# 2019-05-07 02:00:00              NaN            NaN            23.0
# 2019-05-07 03:00:00             50.5           25.0            19.0
# 2019-05-07 04:00:00             45.0           27.7            19.0
# 2019-05-07 05:00:00              NaN           50.4            16.0
# 2019-05-07 06:00:00              NaN           61.9             NaN
#
#                      london_mg_per_cubic
# datetime
# 2019-05-07 02:00:00               43.286
# 2019-05-07 03:00:00               35.758
# 2019-05-07 04:00:00               35.758
# 2019-05-07 05:00:00               30.112
# 2019-05-07 06:00:00                  NaN

# %%
air_quality.info
# Out:
# <bound method DataFrame.info of                      station_antwerp  station_paris  station_london  \
# datetime
# 2019-05-07 02:00:00              NaN            NaN            23.0
# 2019-05-07 03:00:00             50.5           25.0            19.0
# 2019-05-07 04:00:00             45.0           27.7            19.0
# 2019-05-07 05:00:00              NaN           50.4            16.0
# 2019-05-07 06:00:00              NaN           61.9             NaN
# ...                              ...            ...             ...
# 2019-06-20 22:00:00              NaN           21.4             NaN
# 2019-06-20 23:00:00              NaN           24.9             NaN
# 2019-06-21 00:00:00              NaN           26.5             NaN
# 2019-06-21 01:00:00              NaN           21.8             NaN
# 2019-06-21 02:00:00              NaN           20.0             NaN
#
#                      london_mg_per_cubic
# datetime
# 2019-05-07 02:00:00               43.286
# ...

# %%
air_quality["station_paris_vs_antwerp"] = (air_quality["station_paris"] 
                                           / air_quality["station_antwerp"])
air_quality.head()
# Out:
#                      station_antwerp  station_paris  station_london  \
# datetime
# 2019-05-07 02:00:00              NaN            NaN            23.0
# 2019-05-07 03:00:00             50.5           25.0            19.0
# 2019-05-07 04:00:00             45.0           27.7            19.0
# 2019-05-07 05:00:00              NaN           50.4            16.0
# 2019-05-07 06:00:00              NaN           61.9             NaN
#
#                      london_mg_per_cubic  station_paris_vs_antwerp
# datetime
# 2019-05-07 02:00:00               43.286                       NaN
# 2019-05-07 03:00:00               35.758                  0.495050
# 2019-05-07 04:00:00               35.758                  0.615556
# 2019-05-07 05:00:00               30.112                       NaN
# 2019-05-07 06:00:00                  NaN                       NaN

# %%
#I want to rename the data columns to the 
#corresponding station identifiers used by openAQ

air_quality_renamed = air_quality.rename(
    columns = {
        "station_antwerp": "BETR801",
        "station_paris" : "FR04014",
        "station_london" : "London westminster",
        
    })

air_quality_renamed.head()
# Out:
#                      BETR801  FR04014  London westminster  \
# datetime
# 2019-05-07 02:00:00      NaN      NaN                23.0
# 2019-05-07 03:00:00     50.5     25.0                19.0
# 2019-05-07 04:00:00     45.0     27.7                19.0
# 2019-05-07 05:00:00      NaN     50.4                16.0
# 2019-05-07 06:00:00      NaN     61.9                 NaN
#
#                      london_mg_per_cubic  station_paris_vs_antwerp
# datetime
# 2019-05-07 02:00:00               43.286                       NaN
# 2019-05-07 03:00:00               35.758                  0.495050
# 2019-05-07 04:00:00               35.758                  0.615556
# 2019-05-07 05:00:00               30.112                       NaN
# 2019-05-07 06:00:00                  NaN                       NaN

# %%
#The rename() function can be used for both row labels and column labels.
#Provide a dictionary with the keys the current 
#names and the values the new names to update the corresponding names.

#converting 
#the column names to lowercase letters can be done using a function as well:

air_quality_renamed = air_quality_renamed.rename(
    columns = str.lower)
air_quality_renamed.head()
# Out:
#                      betr801  fr04014  london westminster  \
# datetime
# 2019-05-07 02:00:00      NaN      NaN                23.0
# 2019-05-07 03:00:00     50.5     25.0                19.0
# 2019-05-07 04:00:00     45.0     27.7                19.0
# 2019-05-07 05:00:00      NaN     50.4                16.0
# 2019-05-07 06:00:00      NaN     61.9                 NaN
#
#                      london_mg_per_cubic  station_paris_vs_antwerp
# datetime
# 2019-05-07 02:00:00               43.286                       NaN
# 2019-05-07 03:00:00               35.758                  0.495050
# 2019-05-07 04:00:00               35.758                  0.615556
# 2019-05-07 05:00:00               30.112                       NaN
# 2019-05-07 06:00:00                  NaN                       NaN

# %% [markdown]
# REMEMBER
# Create a new column by assigning the output to the DataFrame with a new column name in between the [].
#
# Operations are element-wise, no need to loop over rows.
#
# Use rename with a dictionary or function to rename row labels or column names.

# %% [raw]
# #6. How to calculate summary statistics

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#Aggregating statistics

#What is the average age of the Titanic passengers?

titanic["Age"].mean()

#Different statistics are available and can be applied to columns with 
#numerical data. Operations in general exclude missing data and operate 
#across rows by default.
# Out:
# 29.69911764705882

# %%
titanic[["Age", "Fare"]].median()
# Out:
# Age     28.0000
# Fare    14.4542
# dtype: float64

# %%
titanic[["Age", "Fare"]].describe()
# Out:
#               Age        Fare
# count  714.000000  891.000000
# mean    29.699118   32.204208
# std     14.526497   49.693429
# min      0.420000    0.000000
# 25%     20.125000    7.910400
# 50%     28.000000   14.454200
# 75%     38.000000   31.000000
# max     80.000000  512.329200

# %%
titanic = titanic.rename(columns = str.lower)
titanic
# Out:
#      passengerid  survived  pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   name     sex   age  sibsp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#Instead of the predefined statistics, specific combinations of aggregating 
#statistics for given columns can bedefined using the DataFrame.agg()method:

titanic.agg(
    {
        "age" : ["min", "max", "median", "skew"],
        "fare": ["min", "max", "median", "mean"],
        
    })
# Out:
#               age        fare
# min      0.420000    0.000000
# max     80.000000  512.329200
# median  28.000000   14.454200
# skew     0.389108         NaN
# mean          NaN   32.204208

# %%
#Aggregating statistics grouped by category¶
#What is the average age for male versus female Titanic passengers?


titanic[["sex", "age"]].groupby("sex").mean()
# Out:
#               age
# sex
# female  27.915709
# male    30.726645

# %%
titanic[["sex", "fare"]].groupby("sex").mean()
# Out:
#              fare
# sex
# female  44.479818
# male    25.523893

# %%
titanic.groupby("pclass").mean()
# Out:
#         passengerid  survived        age     sibsp     parch       fare
# pclass
# 1        461.597222  0.629630  38.233441  0.416667  0.356481  84.154687
# 2        445.956522  0.472826  29.877630  0.402174  0.380435  20.662183
# 3        439.154786  0.242363  25.140620  0.615071  0.393075  13.675550

# %%
titanic.groupby("pclass")["survived"].mean()
# Out:
# pclass
# 1    0.629630
# 2    0.472826
# 3    0.242363
# Name: survived, dtype: float64

# %%
titanic.groupby(["sex", "pclass"])["fare"].mean()
# Out:
# sex     pclass
# female  1         106.125798
#         2          21.970121
#         3          16.118810
# male    1          67.226127
#         2          19.741782
#         3          12.661633
# Name: fare, dtype: float64

# %%
titanic.groupby(["sex", "survived","pclass"]).mean()
# Out:
#                         passengerid        age     sibsp     parch        fare
# sex    survived pclass
# female 0        1        325.000000  25.666667  0.666667  1.333333  110.604167
#                 2        423.500000  36.000000  0.500000  0.166667   18.250000
#                 3        440.375000  23.818182  1.291667  1.097222   19.773093
#        1        1        473.967033  34.939024  0.549451  0.428571  105.978159
#                 2        444.785714  28.080882  0.485714  0.642857   22.288989
#                 3        359.083333  19.329787  0.500000  0.500000   12.464526
# male   0        1        413.623377  44.581967  0.272727  0.259740   62.894910
#                 2        454.010989  33.369048  0.307692  0.142857   19.488965
#                 3        456.750000  27.255814  0.523333  0.213333   12.204469
#        1        1        527.777778  36.248000  0.377778  0.311111   74.637320
#                 2        415.588235  16.022000  0.529412  0.647059   21.095100
# ...

# %%
#Grouping can be done by multiple columns at the same time. 
#Provide the column names as a list to the groupby() method.

# %%
#Count number of records by category

#What is the number of passengers in each of the cabin classes?

titanic["pclass"].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: pclass, dtype: int64

# %%
titanic.groupby("pclass")["pclass"].count()
# Out:
# pclass
# 1    216
# 2    184
# 3    491
# Name: pclass, dtype: int64

# %% [markdown]
# REMEMBER
#
# Aggregation statistics can be calculated on entire columns or rows
#
# groupby provides the power of the split-apply-combine pattern
#
# value_counts is a convenient shortcut to count the number of entries in each category of a variable

# %% [markdown]
# 7. how to reshape the layout of tables?

# %%
#Sort table rows
#I want to sort the Titanic data according to the age of the passenger

titanic.sort_values(by = "age").head()
# Out:
#      passengerid  survived  pclass                             name     sex  \
# 803          804         1       3  Thomas, Master. Assad Alexander    male
# 755          756         1       2        Hamalainen, Master. Viljo    male
# 644          645         1       3           Baclini, Miss. Eugenie  female
# 469          470         1       3    Baclini, Miss. Helene Barbara  female
# 78            79         1       2    Caldwell, Master. Alden Gates    male
#
#       age  sibsp  parch  ticket     fare cabin embarked
# 803  0.42      0      1    2625   8.5167   NaN        C
# 755  0.67      1      1  250649  14.5000   NaN        S
# 644  0.75      2      1    2666  19.2583   NaN        C
# 469  0.75      2      1    2666  19.2583   NaN        C
# 78   0.83      0      2  248738  29.0000   NaN        S

# %%
#I want to sort the Titanic data according 
#to the cabin class and age in descending order.

titanic.sort_values(by= ["pclass", "age"], ascending = False).head()
# Out:
#      passengerid  survived  pclass                       name     sex   age  \
# 851          852         0       3        Svensson, Mr. Johan    male  74.0
# 116          117         0       3       Connors, Mr. Patrick    male  70.5
# 280          281         0       3           Duane, Mr. Frank    male  65.0
# 483          484         1       3     Turkula, Mrs. (Hedwig)  female  63.0
# 326          327         0       3  Nysveen, Mr. Johan Hansen    male  61.0
#
#      sibsp  parch  ticket    fare cabin embarked
# 851      0      0  347060  7.7750   NaN        S
# 116      0      0  370369  7.7500   NaN        Q
# 280      0      0  336439  7.7500   NaN        Q
# 483      0      0    4134  9.5875   NaN        S
# 326      0      0  345364  6.2375   NaN        S

# %%
#Long to wide table format¶ continue the rest
